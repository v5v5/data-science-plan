# %% [markdown]
# Данные взяты с сайта https://rp5.ru/Архив_погоды_в_Москве_(ВДНХ)
#
#
# Нажимаем кнопку "Выбрать в файл GZ (архив)" и формат файла Excel файлом за интересующий период (с 2016 года). Рядом появляется ссылка "Скачать". Правая кнопка мыши -> Копировать ссылку
#
# Пример команды для скачивания (подставить свою ссылку):
#
# ```!wget -O "weather.xls.gz" "http://37.9.3.250/download/files.synop/27/27612.01.01.2015.01.01.2021.1.0.0.ru.utf8.00000000.xls.gz"```
#
# Распаковка архива:
#
# ```!gzip -df "weather.xls.gz"```
#
# Ссылка на вебинар
# https://live.skillbox.ru/webinars/code/analiz-dannykh-v-data-science-znakomimsya-s-python130521/

# %% [markdown]
# #Скриншот: получение ссылки на датасет

# %% [markdown]
# ![how2load.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# #1. Введение в Python

# %%
x = 5
y = 6

x+y
# Out:
# 11

# %%
print(x+y, x, y)
# Out:
# 11 5 6

# %%
x
# Out:
# 5

# %%
# Comments start with hash

string = "это строка"
string_b = 'это тоже'
string + ' ' + string_b
# Out:
# 'это строка это тоже'

# %%
y = None  # используется этот тип данных, когда значение неизвестно, заглушка для пустых значений
lst = [1, 2, 3.1416, string, 'hello', None, True, False]  # Список

# %%
t = 36.6
t_2 = 37.2

t < t_2, t > t_2, t >= t_2, t == t_2
# Out:
# (True, False, False, False)

# %%
# t = 36.6
t = 37.5

if t < 37.2:
    print('Здоров')
else:
    print('Болен')
# Out:
# Болен

# %%
# 4 + None  # пример ошибки
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a6d16a4a9815> in <module>()
# ----> 1 4 + None  # пример ошибки
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %% [markdown]
# #2. Matplotlib: графики

# %%
import matplotlib.pyplot as plt  # Подключаем дополнительный модуль

# %%
x = [1, 2, 3, 4, 5]
y = [5, 6, 3, 2, 7]

plt.plot(x, y)

# %%
plt.figure(figsize=(20, 5))
plt.plot(x, y, color='red', label='data')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()

# %% [markdown]
# #3. Pandas: таблицы

# %%
# Скачивание файла (подставить свою ссылку)
# !wget -O "weather.xls.gz" "http://37.9.3.253/download/files.synop/27/27612.13.05.2016.13.05.2021.1.0.0.ru.utf8.00000000.xls.gz"
# Out:
# --2021-05-13 19:26:10--  http://37.9.3.253/download/files.synop/27/27612.13.05.2016.13.05.2021.1.0.0.ru.utf8.00000000.xls.gz
# Connecting to 37.9.3.253:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1213436 (1.2M) [application/octet-stream]
# Saving to: ‘weather.xls.gz’
#
# weather.xls.gz      100%[===================>]   1.16M   865KB/s    in 1.4s
#
# 2021-05-13 19:26:12 (865 KB/s) - ‘weather.xls.gz’ saved [1213436/1213436]

# %%
# Распаковка архива
# !gzip -df "weather.xls.gz"

# %%
import pandas as pd

# %%
data = pd.read_excel('weather.xls', skiprows=6)

# %%
data.head(10)
# Out:
#   Местное время в Москве (ВДНХ)     T     Po  ...   Tg   E'  sss
# 0              13.05.2021 21:00  14.2  748.0  ...  NaN  NaN  NaN
# 1              13.05.2021 18:00  16.4  747.8  ...  NaN  NaN  NaN
# 2              13.05.2021 15:00  19.3  748.7  ...  NaN  NaN  NaN
# 3              13.05.2021 12:00  18.7  749.4  ...  NaN  NaN  NaN
# 4              13.05.2021 09:00  15.0  750.3  ...  9.0  NaN  NaN
# 5              13.05.2021 06:00   9.6  751.0  ...  NaN  NaN  NaN
# 6              13.05.2021 03:00  10.5  750.4  ...  NaN  NaN  NaN
# 7              13.05.2021 00:00  15.0  749.5  ...  NaN  NaN  NaN
# 8              12.05.2021 21:00  15.2  749.7  ...  NaN  NaN  NaN
# 9              12.05.2021 18:00  15.7  750.4  ...  NaN  NaN  NaN
#
# [10 rows x 29 columns]

# %%
data.columns  # атрибут объекта - список колонок
# Out:
# Index(['Местное время в Москве (ВДНХ)', 'T', 'Po', 'P', 'Pa', 'U', 'DD', 'Ff',
#        'ff10', 'ff3', 'N', 'WW', 'W1', 'W2', 'Tn', 'Tx', 'Cl', 'Nh', 'H', 'Cm',
#        'Ch', 'VV', 'Td', 'RRR', 'tR', 'E', 'Tg', 'E'', 'sss'],
#       dtype='object')

# %%
# Pandas DataFrame (наша data) - это таблицы, которые хранятся по столбцам, т.е. если мы хотим получить данные о температуре 
# в строке 15, мы в квадратных скобках пишем сначала название колонки, потом номер строки
data['T']
# Out:
# 0        14.2
# 1        16.4
# 2        19.3
# 3        18.7
# 4        15.0
#          ...
# 14608    13.3
# 14609    11.3
# 14610     6.1
# 14611     6.0
# 14612     8.2
# Name: T, Length: 14613, dtype: float64

# %%
data['T'][0]  # обратите внимание - нумерация в списках и колонках и т.д. во многих языках программирования начинается с 0
# Out:
# 14.2

# %%
data['Местное время в Москве (ВДНХ)'][15]
# Out:
# '12.05.2021 00:00'

# %%
# Преобразовать российский формат дат для дальнейшего анализа
# Для создания нового столбца в таблице достаточно написать новое имя в квадраных скобках и написать "= что-то"
# dayfirst=True помогает работать именно с российским форматом дат
data['date'] = pd.to_datetime(data['Местное время в Москве (ВДНХ)'], dayfirst=True)

# %%
data['date'][15]
# Out:
# Timestamp('2021-05-12 00:00:00')

# %%
x = data['date']
y = data['T']
plt.plot(x, y)

# %%
# Гистограмма - график, который показывает, сколько раз встречалось то или иное значние
data['T'].hist()

# %%
data['T'].max(), data['T'].min(), data['T'].mean()
# Out:
# (33.4, -29.9, 6.979024089789161)

# %%
# Для прогнозирования нужно выявить зависимости от каких-то факторов (для этого генерируем новые факторы)

data['dayofyear'] = data['date'].dt.dayofyear
data['month'] = data['date'].dt.month
data['hour'] = data['date'].dt.hour

# %%
data
# Out:
#       Местное время в Москве (ВДНХ)     T     Po  ...  dayofyear  month  hour
# 0                  13.05.2021 21:00  14.2  748.0  ...        133      5    21
# 1                  13.05.2021 18:00  16.4  747.8  ...        133      5    18
# 2                  13.05.2021 15:00  19.3  748.7  ...        133      5    15
# 3                  13.05.2021 12:00  18.7  749.4  ...        133      5    12
# 4                  13.05.2021 09:00  15.0  750.3  ...        133      5     9
# ...                             ...   ...    ...  ...        ...    ...   ...
# 14608              13.05.2016 12:00  13.3  745.6  ...        134      5    12
# 14609              13.05.2016 09:00  11.3  746.4  ...        134      5     9
# 14610              13.05.2016 06:00   6.1  746.2  ...        134      5     6
# 14611              13.05.2016 03:00   6.0  745.8  ...        134      5     3
# 14612              13.05.2016 00:00   8.2  745.5  ...        134      5     0
#
# [14613 rows x 33 columns]

# %%
# Посмотрим, от какого из признаков больше зависит температура
# Агрегируем данные (по месяцу, по дню в году)

# %%
# Таблица - средняя температрура в месяц
data.groupby('month').mean()
# Out:
#                T          Po           P  ...         Tg   dayofyear       hour
# month                                     ...
# 1      -4.899113  746.696935  761.840645  ...        NaN   16.000000  10.500000
# 2      -5.149645  747.055674  762.225355  ...        NaN   45.602837  10.500000
# 3       0.080403  745.681855  760.518065  ...   1.000000   75.200000  10.500000
# 4       6.710417  746.827333  761.329833  ...   2.024000  105.700000  10.500000
# 5      13.706490  746.955689  761.079567  ...   8.644737  136.301282  10.500000
# 6      17.699417  746.303500  760.208167  ...  13.106667  166.900000  10.500000
# 7      18.955780  743.997496  757.782229  ...  15.272727  197.402262  10.512116
# 8      18.414919  748.205484  762.094194  ...  13.908497  228.400000  10.500000
# 9      13.054083  748.702000  762.885417  ...   9.000000  258.900000  10.500000
# 10      6.964758  749.329032  763.852258  ...   4.641379  289.400000  10.500000
# ...

# %%
data.groupby('month').mean()['T'].plot()

# %%
data.groupby('hour').mean()['T'].plot()

# %%
data.groupby('dayofyear').mean()['T'].plot()

# %%
# Ищем пропущенные значения - NaN, None, NA и т.п. - названия пропущенных значений
condition = data['T'].isna()  # пустые значения
data[condition]  # фильтрация данных в таблице по условию, нашли одно пропущенное значение
# Out:
#      Местное время в Москве (ВДНХ)   T     Po  ...  dayofyear  month  hour
# 2452              11.07.2020 09:00 NaN  746.1  ...        193      7     9
#
# [1 rows x 33 columns]

# %%
# Есть разные стратегии - удалять, заполнять средним значением, наиболее часто встречающимся и т.п. 

# Оставим только непустыне значения в таблице
condition = data['T'].notna()  # НЕпустые значения
data2 = data[condition]

# %%
data2
# Out:
#       Местное время в Москве (ВДНХ)     T     Po  ...  dayofyear  month  hour
# 0                  13.05.2021 21:00  14.2  748.0  ...        133      5    21
# 1                  13.05.2021 18:00  16.4  747.8  ...        133      5    18
# 2                  13.05.2021 15:00  19.3  748.7  ...        133      5    15
# 3                  13.05.2021 12:00  18.7  749.4  ...        133      5    12
# 4                  13.05.2021 09:00  15.0  750.3  ...        133      5     9
# ...                             ...   ...    ...  ...        ...    ...   ...
# 14608              13.05.2016 12:00  13.3  745.6  ...        134      5    12
# 14609              13.05.2016 09:00  11.3  746.4  ...        134      5     9
# 14610              13.05.2016 06:00   6.1  746.2  ...        134      5     6
# 14611              13.05.2016 03:00   6.0  745.8  ...        134      5     3
# 14612              13.05.2016 00:00   8.2  745.5  ...        134      5     0
#
# [14612 rows x 33 columns]

# %%
# Иногда хочется отсечь данные по признаку временному - хотим оставить только первый год


condition = data['date'].dt.year < 2018
data_2017 = data[condition]
plt.figure(figsize=(20, 5))
plt.plot(data_2017['date'], data_2017['T'])

# %%
# Упражнение для самопроверки (присылать на проверку не нужно, можно обсуждать в чате)
# вывести данные с 1 июля 2018 по 7 января 2020
# можно скомбинировать и видоизменить код с вебинара, можно погуглить, как это сделать в одну срочку - главное, чтобы вы убедились, что все работает
